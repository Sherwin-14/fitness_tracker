# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib as mpl

# %%
df = pd.read_pickle('MetaMotion/data_resampled.pkl')

# %%
df.head()
# Out:
#                             acc_x     acc_y     acc_z   gyr_x   gyr_y   gyr_z  \
# epoch (ms)
# 2019-01-11 15:08:05.200  0.013500  0.977000 -0.071000 -1.8904  2.4392  0.9388
# 2019-01-11 15:08:05.400 -0.001500  0.970500 -0.079500 -1.6826 -0.8904  2.1708
# 2019-01-11 15:08:05.600  0.001333  0.971667 -0.064333  2.5608 -0.2560 -1.4146
# 2019-01-11 15:08:05.800 -0.024000  0.957000 -0.073500  8.0610 -4.5244 -2.0730
# 2019-01-11 15:08:06.000 -0.028000  0.957667 -0.115000  2.4390 -1.5486 -3.6098
#
#                         participant  label category  set
# epoch (ms)
# 2019-01-11 15:08:05.200           B  bench    heavy   30
# 2019-01-11 15:08:05.400           B  bench    heavy   30
# 2019-01-11 15:08:05.600           B  bench    heavy   30
# 2019-01-11 15:08:05.800           B  bench    heavy   30
# 2019-01-11 15:08:06.000           B  bench    heavy   30

# %%
set_df = df[df["set"] == 1]

# %%
plt.plot(set_df["acc_x"])

# %%
plt.plot(df["acc_x"])

# %%
plt.plot(set_df["acc_y"].reset_index(drop = True))

# %%
df["label"].unique()
# Out:
# array(['bench', 'ohp', 'squat', 'dead', 'row', 'rest'], dtype=object)

# %%
for label in df["label"].unique() :

    subset = df[df["label"] == label]
    display(subset.head(2))





# --------------------------------------------------------------
# Adjust plot settings
# --------------------------------------------------------------


# --------------------------------------------------------------
# Compare medium vs. heavy sets
# --------------------------------------------------------------


# --------------------------------------------------------------
# Compare participants
# --------------------------------------------------------------


# --------------------------------------------------------------
# Plot multiple axis
# --------------------------------------------------------------


# --------------------------------------------------------------
# Create a loop to plot all combinations per sensor
# --------------------------------------------------------------


# --------------------------------------------------------------
# Combine plots in one figure
# --------------------------------------------------------------


# --------------------------------------------------------------
# Loop over all combinations and export for both sensors
# --------------------------------------------------------------
# Out:
#                           acc_x   acc_y   acc_z   gyr_x   gyr_y   gyr_z  \
# epoch (ms)
# 2019-01-11 15:08:05.200  0.0135  0.9770 -0.0710 -1.8904  2.4392  0.9388
# 2019-01-11 15:08:05.400 -0.0015  0.9705 -0.0795 -1.6826 -0.8904  2.1708
#
#                         participant  label category  set
# epoch (ms)
# 2019-01-11 15:08:05.200           B  bench    heavy   30
# 2019-01-11 15:08:05.400           B  bench    heavy   30
#                             acc_x     acc_y     acc_z   gyr_x   gyr_y   gyr_z  \
# epoch (ms)
# 2019-01-11 15:38:55.000 -0.062500  0.901000  0.047000  0.4390 -6.5000 -0.0854
# 2019-01-11 15:38:55.200 -0.080667  1.080667  0.060333  5.5976 -3.2196 -1.4266
#
#                         participant label category  set
# epoch (ms)
# 2019-01-11 15:38:55.000           A   ohp    heavy    9
# 2019-01-11 15:38:55.200           A   ohp    heavy    9
#                             acc_x     acc_y     acc_z   gyr_x   gyr_y   gyr_z  \
# epoch (ms)
# 2019-01-11 16:05:44.600  0.135333  0.694667  0.735333  2.5366 -0.6220  1.6098
# 2019-01-11 16:05:44.800  0.097500  0.651500  0.658000  2.0854  0.0366  0.1952
#
#                         participant  label category  set
# epoch (ms)
# 2019-01-11 16:05:44.600           A  squat   medium   27
# 2019-01-11 16:05:44.800           A  squat   medium   27
#                             acc_x  acc_y     acc_z      gyr_x    gyr_y  \
# epoch (ms)
# 2019-01-11 16:24:24.800  0.056500 -1.027 -0.165500   3.231667  -2.6830
# 2019-01-11 16:24:25.000  0.073333 -1.025 -0.155333  12.853600 -30.9024
#
#                             gyr_z participant label category  set
# epoch (ms)
# 2019-01-11 16:24:24.800  2.418667           A  dead   medium    6
# 2019-01-11 16:24:25.000  4.487800           A  dead   medium    6
#                           acc_x  acc_y  acc_z    gyr_x   gyr_y   gyr_z  \
# epoch (ms)
# 2019-01-14 14:01:40.000 -0.0370 -0.854  0.271 -31.8172 -1.6830 -6.3660
# 2019-01-14 14:01:40.200 -0.0425 -0.884  0.174 -56.3416 -8.3172 -9.9388
#
#                         participant label category  set
# epoch (ms)
# 2019-01-14 14:01:40.000           C   row   medium   51
# 2019-01-14 14:01:40.200           C   row   medium   51
#                             acc_x     acc_y     acc_z   gyr_x   gyr_y   gyr_z  \
# epoch (ms)
# 2019-01-18 17:22:26.000  0.980667 -0.069333 -0.185667  0.5978 -1.3538  0.6100
# 2019-01-18 17:22:26.200  0.985500 -0.067500 -0.185500  2.6710  2.1952  0.1952
#
#                         participant label category  set
# epoch (ms)
# 2019-01-18 17:22:26.000           A  rest  sitting   18
# 2019-01-18 17:22:26.200           A  rest  sitting   18

# %%
import plotly.graph_objects as go

# %%
for label in df["label"].unique() :

    subset = df[df["label"] == label]
    fig = go.Figure()
    fig.add_trace(go.Scatter(y=set_df["acc_y"].reset_index(drop=True), mode='lines', name=label))
    fig.update_layout(title='Accelerometer Readings',
                  xaxis_title='Sample Number',
                  yaxis_title='Acceleration (y-axis)')
    fig.show()





# --------------------------------------------------------------
# Adjust plot settings
# --------------------------------------------------------------


# --------------------------------------------------------------
# Compare medium vs. heavy sets
# --------------------------------------------------------------


# --------------------------------------------------------------
# Compare participants
# --------------------------------------------------------------


# --------------------------------------------------------------
# Plot multiple axis
# --------------------------------------------------------------


# --------------------------------------------------------------
# Create a loop to plot all combinations per sensor
# --------------------------------------------------------------


# --------------------------------------------------------------
# Combine plots in one figure
# --------------------------------------------------------------


# --------------------------------------------------------------
# Loop over all combinations and export for both sensors
# --------------------------------------------------------------

# %% [markdown]
# No kernel connected
